# %% [markdown]
# # Guidelines for AI-assisted Coding
# In this lesson, you'll practice AI-assisted coding. This will help you to use AI to assist your coding tasks
#
# ## Setup
# #### Load the API key and relevant Python libaries.

# %% [markdown]
# For demonstation, I will use OpenAI API key

# %%
# !pip install python-dotenv --quiet

# %%
import openai
import os

# Get secret API key
"""
openai_api_key = os.environ.get("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("OpenAI API Key not found in Colab secrets!")
"""
# Set it as environment variable
os.environ["OPENAI_API_KEY"] = 'YOUR_KEY'

print("API Key Loaded Successfully!")
# Out:
# API Key Loaded Successfully!

# %% [markdown]
# **Helper function** <br>
# <br>
# Throughout this demo, we will use OpenAI's gpt-4o-mini model and the chat completions endpoint.
# <br>
# This helper function will make it easier to use prompts and look at the generated outputs. <br>

# %%
from openai import OpenAI
client = OpenAI()

def get_completion(prompt, model="gpt-4o-mini", temperature=0.5, \
                   max_tokens=40, top_p=0.9, logprobs=False):
     messages=[{"role": "user", "content": prompt}]
     response = client.chat.completions.create(
         model=model,
         messages=messages,
         temperature=temperature,
         max_tokens=max_tokens,
         top_p=top_p,
         logprobs=logprobs

     )

     return response.choices[0].message.content

# %% [markdown]
# ## 1. Cosine Similarity Function Generation with Prompt
#
# **Prompt:** Write a Python function to calculate the cosine similarity between two non-zero vectors. Show example usages.
#
# **Input Code:**

# %%
# Load library for code formatting (in output)
from rich.syntax import Syntax
from rich.console import Console

# %%
# Define prompt
prompt = """
Write a Python function to calculate the cosine similarity between two non-zero vectors. Show example usages
"""

# Execute the prompt
response = get_completion(prompt, temperature=0.3, max_tokens=600, top_p=1)

console = Console()
syntax = Syntax(response, "python", theme="monokai", line_numbers=False)
console.print(syntax)
# Out:
# Certainly! Cosine similarity is a measure of similarity between two non-zero vectors that calculates the cosine of
#
# Here's a Python function to calculate the cosine similarity between two non-zero vectors, along with example usages
#
# ```python
# import numpy as np
#
# def cosine_similarity(vec1, vec2):
#     """
#     Calculate the cosine similarity between two non-zero vectors.
#
#     Parameters:
#     vec1 (list or np.ndarray): First vector
#     vec2 (list or np.ndarray): Second vector
#
#     Returns:
#     float: Cosine similarity between vec1 and vec2
#     """
#     # Convert to numpy arrays
#     vec1 = np.array(vec1)
#     vec2 = np.array(vec2)
#
#     # Check if the vectors are non-zero
#     if np.linalg.norm(vec1) == 0 or np.linalg.norm(vec2) == 0:
#         raise ValueError("Vectors must be non-zero.")
#
#     # Calculate the dot product and magnitudes
#     dot_product = np.dot(vec1, vec2)
#     magnitude_vec1 = np.linalg.norm(vec1)
#     magnitude_vec2 = np.linalg.norm(vec2)
#
#     # Calculate cosine similarity
#     similarity = dot_product / (magnitude_vec1 * magnitude_vec2)
#     return similarity
#
# # Example usages
# if __name__ == "__main__":
#     vector_a = [1, 2, 3]
#     vector_b = [4, 5, 6]
#     vector_c = [1, 0, 0]
#
#     # Calculate cosine similarity between vector_a and vector_b
#     similarity_ab = cosine_similarity(vector_a, vector_b)
#     print(f"Cosine similarity between vector_a and vector_b: {similarity_ab}")
#
#     # Calculate cosine similarity between vector_a and vector_c
#     similarity_ac = cosine_similarity(vector_a, vector_c)
#     print(f"Cosine similarity between vector_a and vector_c: {similarity_ac}")
#
#     # Calculate cosine similarity between vector_b and vector_c
#     similarity_bc = cosine_similarity(vector_b, vector_c)
#     print(f"Cosine similarity between vector_b and vector_c: {similarity_bc}")
# ```
#
# ### Example Output
# When you run the code, you might see output similar to the following:
#
# ```
# Cosine similarity between vector_a and vector_b: 0.9746318461970762
# Cosine similarity between vector_a and vector_c: 1.0
# Cosine similarity between vector_b and vector_c: 0.9746318461970762
# ```
#
# ### Explanation
# - The function `cosine_similarity` takes two vectors as input and calculates their cosine similarity.
# - It first checks if either vector is a zero vector and raises an error if so.
# - It then computes the dot product and the magnitudes of the vectors to calculate the cosine similarity.
# - Finally,

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    """
    Calculate the cosine similarity between two non-zero vectors.

    Parameters:
    vec1 (list or np.ndarray): First vector
    vec2 (list or np.ndarray): Second vector

    Returns:
    float: Cosine similarity between vec1 and vec2
    """
    # Convert to numpy arrays
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)

    # Check if the vectors are non-zero
    if np.linalg.norm(vec1) == 0 or np.linalg.norm(vec2) == 0:
        raise ValueError("Vectors must be non-zero.")

    # Calculate the dot product and magnitudes
    dot_product = np.dot(vec1, vec2)
    magnitude_vec1 = np.linalg.norm(vec1)
    magnitude_vec2 = np.linalg.norm(vec2)

    # Calculate cosine similarity
    similarity = dot_product / (magnitude_vec1 * magnitude_vec2)
    return similarity

# Example usages
if __name__ == "__main__":
    vector_a = [1, 2, 3]
    vector_b = [4, 5, 6]
    vector_c = [1, 0, 0]

    # Calculate cosine similarity between vector_a and vector_b
    similarity_ab = cosine_similarity(vector_a, vector_b)
    print(f"Cosine similarity between vector_a and vector_b: {similarity_ab}")

    # Calculate cosine similarity between vector_a and vector_c
    similarity_ac = cosine_similarity(vector_a, vector_c)
    print(f"Cosine similarity between vector_a and vector_c: {similarity_ac}")

    # Calculate cosine similarity between vector_b and vector_c
    similarity_bc = cosine_similarity(vector_b, vector_c)
    print(f"Cosine similarity between vector_b and vector_c: {similarity_bc}")
# Out:
# Cosine similarity between vector_a and vector_b: 0.9746318461970762
# Cosine similarity between vector_a and vector_c: 0.2672612419124244
# Cosine similarity between vector_b and vector_c: 0.4558423058385518

# %% [markdown]
# ## 2. Bug Identification
#
# **Prompt:** Identify the bug in the following function that calculates the factorial of a number.
#
# **Input Code:**

# %%
# Define prompt
prompt = """
Identify the bug in the following function that calculates the factorial of a number.
"""

# Code to pass
input_code = """
def factorial(n):
    result = 1
    for i in range(1, n):  # Bug: This should be range(1, n+1)
        result *= i
    return result

# Example usage
factorial(5)
"""

# %%
response = get_completion(prompt + ":" + input_code, temperature=0.3, max_tokens=400, top_p=1)

console = Console()
syntax = Syntax(response, "python", theme="monokai", line_numbers=False)
console.print(syntax)
# Out:
# The bug in the provided `factorial` function is indeed in the range used in the for loop. The current implementatio
#
# To fix this, you should change the range to `range(1, n + 1)`, which will include `n` in the multiplication. Here i
#
# ```python
# def factorial(n):
#     result = 1
#     for i in range(1, n + 1):  # Fixed: Now includes n
#         result *= i
#     return result
#
# # Example usage
# print(factorial(5))  # This will now correctly output 120
# ```
#
# With this change, calling `factorial(5)` will correctly return `120`, which is the factorial of 5 (i.e., 5 * 4 * 3

# %% [markdown]
# ## 3. Commenting the Code
#
# **Prompt:** Add comments to the following code that reverses a string.
#
# **Input Code:**

# %%
# Define prompt
prompt = """
Add comments to the following code.
"""

# Code to pass
input_code = """
import datetime
import uuid

class Task:
    def __init__(self, title, description, due_date):
        self.id = str(uuid.uuid4())
        self.title = title
        self.description = description
        self.due_date = datetime.datetime.strptime(due_date, "%Y-%m-%d")
        self.created_at = datetime.datetime.now()
        self.completed = False

    def mark_complete(self):
        self.completed = True

    def is_overdue(self):
        return not self.completed and datetime.datetime.now() > self.due_date

    def __str__(self):
        status = "Completed" if self.completed else "Pending"
        return f"[{status}] {self.title} - Due: {self.due_date.strftime('%Y-%m-%d')}"

class TaskManager:
    def __init__(self):
        self.tasks = []

    def add_task(self, title, description, due_date):
        task = Task(title, description, due_date)
        self.tasks.append(task)
        return task.id

    def get_task(self, task_id):
        for task in self.tasks:
            if task.id == task_id:
                return task
        return None

    def mark_task_complete(self, task_id):
        task = self.get_task(task_id)
        if task:
            task.mark_complete()
            return True
        return False

    def list_tasks(self):
        return sorted(self.tasks, key=lambda x: x.due_date)

    def list_overdue_tasks(self):
        return [task for task in self.tasks if task.is_overdue()]

def main():
    manager = TaskManager()
    task1_id = manager.add_task("Complete report", "Finish the annual report", "2025-02-15")
    task2_id = manager.add_task("Doctor appointment", "Visit Dr. Smith at 10 AM", "2025-01-25")
    task3_id = manager.add_task("Grocery shopping", "Buy milk, eggs, and bread", "2025-01-30")

    manager.mark_task_complete(task1_id)

    print("All Tasks:")
    for task in manager.list_tasks():
        print(task)

    print("\nOverdue Tasks:")
    for task in manager.list_overdue_tasks():
        print(task)

if __name__ == "__main__":
    main()

"""

# %%
response = get_completion(prompt + ":" + input_code, temperature=0.3, max_tokens=1000, top_p=1)

console = Console()
syntax = Syntax(response, "python", theme="monokai", line_numbers=False)
console.print(syntax)
# Out:
# Here are the comments added to the provided code to explain its functionality:
#
# ```python
# import datetime  # Import the datetime module for handling date and time
# import uuid      # Import the uuid module for generating unique identifiers
#
# # Define the Task class to represent a single task
# class Task:
#     def __init__(self, title, description, due_date):
#         # Generate a unique ID for the task
#         self.id = str(uuid.uuid4())
#         # Set the title of the task
#         self.title = title
#         # Set the description of the task
#         self.description = description
#         # Convert the due_date string into a datetime object
#         self.due_date = datetime.datetime.strptime(due_date, "%Y-%m-%d")
#         # Record the time the task was created
#         self.created_at = datetime.datetime.now()
#         # Initialize the task as not completed
#         self.completed = False
#
#     # Method to mark the task as complete
#     def mark_complete(self):
#         self.completed = True
#
#     # Method to check if the task is overdue
#     def is_overdue(self):
#         # A task is overdue if it is not completed and the current date is past the due date
#         return not self.completed and datetime.datetime.now() > self.due_date
#
#     # String representation of the task for easy display
#     def __str__(self):
#         # Determine the status of the task (Completed or Pending)
#         status = "Completed" if self.completed else "Pending"
#         # Return a formatted string with the task's status, title, and due date
#         return f"[{status}] {self.title} - Due: {self.due_date.strftime('%Y-%m-%d')}"
#
# # Define the TaskManager class to manage multiple tasks
# class TaskManager:
#     def __init__(self):
#         # Initialize an empty list to hold tasks
#         self.tasks = []
#
#     # Method to add a new task to the manager
#     def add_task(self, title, description, due_date):
#         # Create a new Task object
#         task = Task(title, description, due_date)
#         # Add the task to the list of tasks
#         self.tasks.append(task)
#         # Return the unique ID of the newly added task
#         return task.id
#
#     # Method to retrieve a task by its ID
#     def get_task(self, task_id):
#         # Iterate through the list of tasks to find the one with the matching ID
#         for task in self.tasks:
#             if task.id == task_id:
#                 return task  # Return the found task
#         return None  # Return None if no task with the given ID is found
#
#     # Method to mark a task as complete using its ID
#     def mark_task_complete(self, task_id):
#         # Retrieve the task using its ID
#         task = self.get_task(task_id)
#         if task:
#             # Mark the task as complete if it exists
#             task.mark_complete()
#             return True  # Return True to indicate success
#         return False  # Return False if the task was not found
#
#     # Method to list all tasks sorted by their due date
#     def list_tasks(self):
#         return sorted(self.tasks, key=lambda x: x.due_date)
#
#     # Method to list all overdue tasks
#     def list_overdue_tasks(self):
#         # Return a list of tasks that are overdue
#         return [task for task in self.tasks if task.is_overdue()]
#
# # Main function to demonstrate the TaskManager functionality
# def main():
#     # Create an instance of TaskManager
#     manager = TaskManager()
#     # Add some tasks and store their IDs
#     task1_id = manager.add_task("Complete report", "Finish the annual report", "2025-02-15")
#     task2_id = manager.add_task("Doctor appointment", "Visit Dr. Smith at 10 AM", "2025-01-25")
#     task3_id = manager.add_task("Grocery shopping", "Buy milk, eggs, and bread", "2025-01-30")
#
#     # Mark the first task as complete
#     manager.mark_task_complete(task1_id)
#
#     # Print all tasks
#     print("All Tasks:")
#     for task in manager.list_tasks():
#         print(task)
#
#     # Print overdue tasks
#     print("Overdue Tasks:")
#     for task in manager.list_overdue_tasks():
#         print(task)
#
# # Entry point of the script
# if __name__ == "__main__":
#     main()  # Call the main function to execute the program
# ```
#
# These comments provide a clear understanding of each part of the code and its purpose, making it easier for someone

# %% [markdown]
# ## 4. Creating Unit Tests
#
# **Prompt:** Write unit tests for the `add` function that adds two numbers.
#
# **Input Code:**

# %%
prompt1 = "Write unit tests for the `add` function that adds two numbers."

# %%
response = get_completion(prompt1, temperature=0.3, max_tokens=400, top_p=1)

console = Console()
syntax = Syntax(response, "python", theme="monokai", line_numbers=False)
console.print(syntax)
# Out:
# Certainly! Below are some example unit tests for a simple `add` function that adds two numbers. I'll provide the im
#
# ### Implementation of the `add` function
#
# ```python
# def add(a, b):
#     return a + b
# ```
#
# ### Unit Tests for the `add` function
#
# ```python
# import unittest
#
# class TestAddFunction(unittest.TestCase):
#
#     def test_add_positive_numbers(self):
#         self.assertEqual(add(2, 3), 5)
#         self.assertEqual(add(10, 15), 25)
#
#     def test_add_negative_numbers(self):
#         self.assertEqual(add(-1, -1), -2)
#         self.assertEqual(add(-5, -10), -15)
#
#     def test_add_mixed_numbers(self):
#         self.assertEqual(add(-1, 1), 0)
#         self.assertEqual(add(5, -3), 2)
#
#     def test_add_zero(self):
#         self.assertEqual(add(0, 0), 0)
#         self.assertEqual(add(0, 5), 5)
#         self.assertEqual(add(5, 0), 5)
#
#     def test_add_floats(self):
#         self.assertAlmostEqual(add(1.5, 2.5), 4.0)
#         self.assertAlmostEqual(add(-1.1, 1.1), 0.0)
#
#     def test_add_large_numbers(self):
#         self.assertEqual(add(10**6, 10**6), 2 * 10**6)
#         self.assertEqual(add(-10**6, 10**6), 0)
#
# if __name__ == '__main__':
#     unittest.main()
# ```
#
# ### Explanation of the Tests
#
# 1. **Positive Numbers**: Tests the addition of two positive integers.
# 2. **Negative Numbers**: Tests the addition

# %% [markdown]
# ## 5. Code Conversion: From R to Python
#
# **Prompt:** Convert the following R function to Python function.
#
# **Input Code:**

# %%
# Define prompt
prompt = """
Convert the following R function to Python function.
"""

# Code to pass
input_code = """
### Input R code
mean_calculation <- function(x) {
  n <- length(x)
  total <- sum(x)
  mean <- total / n
  return(mean)
}

# Example usage
mean_calculation(c(1, 2, 3, 4, 5))
"""

# %%
response = get_completion(prompt + ":" + input_code, temperature=0.3, max_tokens=1000, top_p=1)

console = Console()
syntax = Syntax(response, "python", theme="monokai", line_numbers=False)
console.print(syntax)
# Out:
# You can convert the provided R function to a Python function as follows:
#
# ### Python Code
#
# ```python
# def mean_calculation(x):
#     n = len(x)
#     total = sum(x)
#     mean = total / n
#     return mean
#
# # Example usage
# print(mean_calculation([1, 2, 3, 4, 5]))
# ```
#
# ### Explanation:
# - The `length` function in R is replaced with `len` in Python.
# - The `sum` function works the same way in both languages.
# - The division operator `/` behaves the same in both R and Python for floating-point division.
# - The input in Python is a list (using square brackets) instead of a vector (using `c()` in R).

# %% [markdown]
# ## 6. Refactoring Code
#
# **Prompt:**  Refactor the following Python function to improve readability and efficiency.
#
#
# **Input Code:**

# %%
# Define prompt
prompt = """
Refactor the following Python function to improve readability and efficiency.
"""

# Unfactored code to pass
unfactored_code = """

items = [
    {"name": "Laptop", "price": 1000, "quantity": 1},
    {"name": "Mouse", "price": 50, "quantity": 2},
    {"name": "Keyboard", "price": 80, "quantity": 1}
]

tax_rate = 0.08

total = 0
for item in items:
    subtotal = item["price"] * item["quantity"]
    tax = subtotal * tax_rate
    total += subtotal + tax
    print(item["name"] + " Subtotal: $" + str(subtotal) + " Tax: $" + str(tax))

print("Total Price: $" + str(total))
"""

# %%
response = get_completion(prompt + ":" + unfactored_code, model = 'gpt-4o', temperature=0.7, max_tokens=1000, top_p=1)

console = Console()
syntax = Syntax(response, "python", theme="monokai", line_numbers=False)
console.print(syntax)
# Out:
# To improve the readability and efficiency of the function, you can refactor the code by encapsulating functionality
#
# ```python
# def calculate_item_total(item, tax_rate):
#     """Calculate the total price for an item including tax."""
#     subtotal = item["price"] * item["quantity"]
#     tax = subtotal * tax_rate
#     total_price = subtotal + tax
#     return subtotal, tax, total_price
#
# def print_item_details(item, subtotal, tax):
#     """Print the details of each item."""
#     print(f"{item['name']} Subtotal: ${subtotal:.2f} Tax: ${tax:.2f}")
#
# def calculate_total(items, tax_rate):
#     """Calculate the total cost for all items including tax and print each item's details."""
#     total = 0
#     for item in items:
#         subtotal, tax, item_total = calculate_item_total(item, tax_rate)
#         print_item_details(item, subtotal, tax)
#         total += item_total
#     return total
#
# def main():
#     items = [
#         {"name": "Laptop", "price": 1000, "quantity": 1},
#         {"name": "Mouse", "price": 50, "quantity": 2},
#         {"name": "Keyboard", "price": 80, "quantity": 1}
#     ]
#
#     tax_rate = 0.08
#     total = calculate_total(items, tax_rate)
#     print(f"Total Price: ${total:.2f}")
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### Key Improvements:
# 1. **Helper Functions**: The code now uses `calculate_item_total` and `print_item_details` functions to separate co
# 2. **Formatted Strings**: Using formatted string literals (f-strings) improves readability, especially for printing
# 3. **Encapsulation**: The `calculate_total` function handles the iteration and cumulative total calculation, while

# %% [markdown]
# ## 7. Enhance Prompts
#
# **Prompt:**  Improve the following prompt to be more specific and clear:
#
# **Original Prompt:** Write a function to calculate the area.

# %%
# Define prompt
prompt = """
Improve the following prompt to be more specific and clear:
"""

# Define original prompt to enhance
original_prompt = """
Write a function to calculate the area.
"""

# %%
improved_prompt = get_completion(prompt + " " + original_prompt, temperature=0.7, max_tokens=1000, top_p=1)
print(improved_prompt)
# Out:
# Please write a Python function named `calculate_area` that takes two parameters: `length` and `width`. The function should return the area of a rectangle calculated using the formula: area = length * width. Ensure that the function handles potential input errors by checking if the provided values are positive numbers. If either value is negative or not a number, the function should return an error message.
